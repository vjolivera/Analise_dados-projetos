# %% [markdown]
# <a href="https://colab.research.google.com/github/vjolivera/Analise_dados-projetos/blob/main/Dados_Sus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploração dos dados do data sus 2008 pra frente

# %%
import pandas as pd
#importação da biblioteca Pandas

# %%
dados = pd.read_csv('/content/A120155189_28_143_208.csv',encoding = 'ISO-8859-1',
                    skiprows = 3, sep=';',skipfooter=12,
                    thousands = ".", decimal =',')
dados
#Na importação dos arquivos ocorreram os seguintes problemas:
# 1º ocorreu uym erro de enconding do arquivo, por isso foi nessesário utilizar
# a função enconding junto coma norma UTF-8
# O separador não era ',' e sim ';', foi nessesário mudar o separador
# Remoção das primieras 3 linhas e da últimas 12 linhas coma  função skip
# Python não idenficou os numeros como float, foi preciso mudar o 
# separador de milhar e de decimal
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unidade da Federação    2008/Jan  ...     2021/Mar          Total
# 0              11 Rondônia  1388528.39  ...  11023309.47   996411254.68
# 1                  12 Acre   902416.00  ...   4077045.92   450048530.47
# 2              13 Amazonas  4735529.42  ...  22032176.22  1917247936.05
# 3               14 Roraima   657889.53  ...   3985530.08   328876965.09
# 4                  15 Pará 18864744.11  ...  33276392.89  4705309002.29
# 5                 16 Amapá  1120973.34  ...   3188210.98   309860092.59
# 6             17 Tocantins  3441592.69  ...   1357751.33  1020028272.64
# 7              21 Maranhão 10723506.39  ...  39663677.48  3871069498.04
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação    2008/Jan  ...     2021/Mar          Total
# 22   43 Rio Grande do Sul 30931325.46  ... 130155185.16 12764391179.92
# 23  50 Mato Grosso do Sul  5377392.11  ...  25168195.34  2324525096.33
# 24         51 Mato Grosso  4795299.01  ...  19611032.61  2180119781.15
# 25               52 Goiás 15310637.29  ...  45592686.49  4973573613.47
# 26    53 Distrito Federal  4745919.19  ...  31831917.45  2592422853.56
#
# [5 rows x 161 columns]

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
dados.mean() #Média dos dados
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %%
dados['2021/Mar']
# Uma série é uma única coluna de um dataframe
# Out:
# 0     11023309.47
# 1      4077045.92
# 2     22032176.22
# 3      3985530.08
# 4     33276392.89
# 5      3188210.98
# 6      1357751.33
# 7     39663677.48
# 8     20018325.75
# 9     62079618.54
# 10    23306498.68
# 11    25750897.89
# 12    83870992.73
# 13    22118639.05
# 14    13321494.41
# 15    98746333.07
# 16   200471045.07
# 17    45490499.45
# 18   106837295.81
# 19   392946147.42
# 20   140264608.52
# 21    81376630.57
# 22   130155185.16
# 23    25168195.34
# 24    19611032.61
# 25    45592686.49
# 26    31831917.45
# Name: 2021/Mar, dtype: float64

# %%
dados['2021/Mar'].mean()
#Média da coluna 2021/Mar
# Out:
# 62502301.42148148

# %%
dados.plot(x="Unidade da Federação", y= "2021/Mar", kind = 'bar',figsize=(9,6))
plt.show()

#primiera exploração dos dados

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.style.use('ggplot')
ax = dados.plot(x="Unidade da Federação", y= "2021/Mar", kind = 'bar',figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}') )#Desafio 1 e dois
plt.title('Valor total gasto , no sistema SUS,  por estado em Março de 2021')
plt.show()

#Vizualização dos dados com tratamento para formatação do eixo Y
